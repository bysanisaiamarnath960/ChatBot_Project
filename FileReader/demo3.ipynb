# %%
# !pip install streamlit
# Out:
# ...
#                                               0.0/8.1 MB ? eta -:--:--
#      ---                                      0.7/8.1 MB 21.5 MB/s eta 0:00:01
#      --------                                 1.7/8.1 MB 21.5 MB/s eta 0:00:01
#      -------------                            2.7/8.1 MB 21.9 MB/s eta 0:00:01
#      --------------------                     4.2/8.1 MB 22.3 MB/s eta 0:00:01
#      ----------------------------             5.7/8.1 MB 24.2 MB/s eta 0:00:01
#      -------------------------------          6.4/8.1 MB 22.7 MB/s eta 0:00:01
#      ---------------------------------------  8.1/8.1 MB 24.7 MB/s eta 0:00:01
#      ---------------------------------------- 8.1/8.1 MB 22.6 MB/s eta 0:00:00
# ...
#                                               0.0/996.9 kB ? eta -:--:--
#      ------------------------------------- 996.9/996.9 kB 31.8 MB/s eta 0:00:00
# ...
#                                               0.0/97.9 kB ? eta -:--:--
# ...
